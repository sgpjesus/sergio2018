# %%
import sys
sys.path.append(r'C:\Users\sergiojesus\Desktop\Diogo2017\EQS_LOCAL\Bitbucket_eqs')
import analytics_stat.db_mgmt as db
import pandas as pd
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from spacy.tokenizer import Tokenizer
from spacy.vocab import Vocab
from spacy.language import Language
import re
from scipy.sparse import find
import numpy as np

# %%
nlp = Language(Vocab()) #Spacy variables
tokenizer = Tokenizer(nlp.vocab)
def tokenization_process(string):
    """tokenizes one string, removing not used punctuation in portuguese language in the process"""
    aux = tokenizer(string)
    output = list()
    for index, word in enumerate(aux):
        if re.search('([A-Za-zÀ-ÿ]+(-|\.)[A-Za-zÀ-ÿ]+|[A-Za-zÀ-ÿ]+)', str(word)):
                output.append(str(re.search('([A-Za-zÀ-ÿ]+(-|\.)[A-Za-zÀ-ÿ]+|[A-Za-zÀ-ÿ]+)', str(word)).group(0)).lower())
    return output

# %%
engine = db.db_engine()
# Out:
# postgresql+psycopg2://analytic:analytic#32@web566.webfaction.com:5432/analytics
# Engine(postgresql+psycopg2://analytic:***@web566.webfaction.com:5432/analytics)

# %%
engine.table_names()
# Out:
# ['clients', 'reliability']

# %%
reliability_table = pd.read_sql('clients', engine)

# %%
reliability_table
# Out:
#    id                name         tk_no tk_datetime tk_header_short  \
# 0   1  ANA (TODAS PONTES)          None        None            None
# 1   2   ANA (incidencias)      ticketid  reportdate    descrição_CI
# 2   3           ANA (OTs)          None  reportdate            None
# 3   4               SHELL  Notification        None            None
# 4   5              MANOLO          None        None            None
# 5   6            SONAE UK          None        None            None
#
#   tk_header_long       tk_priority scenario_sft_conse scenario_envir_conse  \
# 0           None              None               None                 None
# 1           None  internalpriority               None                 None
# 2           None              None               None                 None
# 3           None              None               None                 None
# 4           None              None               None                 None
# ...

# %%
dataframe = pd.read_csv('C:/Users/sergiojesus/Desktop/Recursos/Dados/Historico_de_la_Astilladora.csv', delimiter= '|', encoding = 'mbcs')

# %%
dataframe
# Out:
#      Unnamed: 0     S  Cl.   Inic.prog.  Fin progr.  Orden         \
# 0           NaN        COR1                          100000015296
# 1           NaN        COR1                          100000016151
# 2           NaN        COR1                          100000017011
# 3           NaN        COR1                          100000018268
# 4           NaN        COR1                          100000025435
# 5           NaN        COR1                          100000025840
# 6           NaN        COR1                          100000026184
# 7           NaN        COR1                          100000026185
# 8           NaN        COR1                          100000041973
# 9           NaN        COR1                          100000042368
# 10          NaN        PRV2  10.04.2012  10.04.2012  100000213599
# 11          NaN        PRV2  14.06.2012  14.06.2012  100000226844
# 12          NaN        PRV2  15.06.2012  15.06.2012  100000227091
# ...

# %%
dataframe = dataframe.drop(columns = ['Unnamed: 0','Unnamed: 16'])

# %%
dataframe = dataframe.rename(columns=dictionary)

# %%
dictionary = {'Orden       ':'wo_no', 'Texto breve                             ':'wo_header_short',
              'Denominación de la ubicación técnica    ':'op_unit_desc',
              'Equipo        ':'eq_id', 'Status del sistema                ':'wo_status', 'Cl. ':'wo_type', 'P':'wo_priority',
              'Fin progr.':'wo_finish_datetime', 'TotGenPlan':'wo_plan_cost', ' TotGenReal':'wo_total_cost'}

# %%
print(dataframe.columns.values)
# Out:
# ['   S' 'Cl. ' 'Inic.prog.' 'Fin progr.' 'Orden       '
#  'Ubicación técnica     ' 'Equipo        '
#  'Denominación de la ubicación técnica    '
#  'Texto breve                             ' 'Pl.MantPrv' 'P' 'PtoTrbRes'
#  'TotGenPlan' ' TotGenReal' 'Status del sistema                ']

# %%
dataframe = dataframe.drop(columns=['   S', 'Inic.prog.','Ubicación técnica     ','Pl.MantPrv', 'PtoTrbRes'])

# %%
dataframe
# Out:
#     wo_type wo_finish_datetime         wo_no           eq_id  \
# 0      COR1                     100000015296  45200000100001
# 1      COR1                     100000016151
# 2      COR1                     100000017011
# 3      COR1                     100000018268
# 4      COR1                     100000025435
# 5      COR1                     100000025840
# 6      COR1                     100000026184
# 7      COR1                     100000026185
# 8      COR1                     100000041973
# 9      COR1                     100000042368
# 10     PRV2         10.04.2012  100000213599
# 11     PRV2         14.06.2012  100000226844
# 12     PRV2         15.06.2012  100000227091
# 13     PRV2         03.07.2012  100000230602
# 14     COR1         20.08.2012  100000238789  45200000100001
# 15     PRV1         24.09.2012  100000245328  45200000100001
# 16     PRV2         08.03.2013  100000274477
# 17     PRV1         23.04.2013  100000283214
# ...

# %%
newdataframe = pd.DataFrame()
for value in dataframe.columns.values:
    newlist = dataframe[value].values
    newerlist = list()
    flag = 0
    for line in newlist:
        if type(line) == str:
            newerlist.append(line.strip())
            flag = 1
    if flag == 0:
        newdataframe[value] = newlist
    else:
        newdataframe[value] = newerlist

# %%
newerlist
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC KKMP MOVM NLIQ PREC',
#  'CTEC KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPP KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'LIB. IMPR KKMP MOVM NLIQ PREC',
#  'LIB. IMPP KKMP MOVM NLIQ PREC',
#  'LIB. IMPP KKMP MOVM NLIQ PREC',
#  'CTEC IMPP KKMP MOVM NLIQ PREC',
#  'LIB. IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPP KKMP MOVM NLIQ PREC',
#  'CTEC IMPR KKMP MOVM NLIQ PREC',
#  'CTEC IMPP KKMP MOVM NLIQ PREC',
# ...

# %%
newlist
# Out:
# array(['                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        '                                  ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC KKMP MOVM NLIQ PREC          ',
#        'CTEC KKMP MOVM NLIQ PREC          ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC KKMP MOVM NLIQ PREC          ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC IMPR KKMP MOVM NLIQ PREC     ',
#        'CTEC KKMP MOVM NLIQ PREC          ',
# ...

# %%
newdataframe[value] = newerlist

# %%
newdataframe
# Out:
#     wo_type wo_finish_datetime         wo_no           eq_id  \
# 0      COR1                     100000015296  45200000100001
# 1      COR1                     100000016151
# 2      COR1                     100000017011
# 3      COR1                     100000018268
# 4      COR1                     100000025435
# 5      COR1                     100000025840
# 6      COR1                     100000026184
# 7      COR1                     100000026185
# 8      COR1                     100000041973
# 9      COR1                     100000042368
# 10     PRV2         10.04.2012  100000213599
# 11     PRV2         14.06.2012  100000226844
# 12     PRV2         15.06.2012  100000227091
# 13     PRV2         03.07.2012  100000230602
# 14     COR1         20.08.2012  100000238789  45200000100001
# 15     PRV1         24.09.2012  100000245328  45200000100001
# 16     PRV2         08.03.2013  100000274477
# 17     PRV1         23.04.2013  100000283214
# ...

# %%
('reliability.csv', encoding = 'utf-8')

# %%
documents = newdataframe['wo_header_short'].values

# %%
documents
# Out:
# array(['sus. placa desgaste cuchilla', 'sustitución correas astilladora',
#        'sus rodillo pinchos astilladora',
#        'limpieza mandibula astilladora', 'sus. correas astilladora',
#        'sus. rodillo pinchos alimet astilladora',
#        'SUS. PEINE ENTRADA ASTILLADORA',
#        'SUS. CONTRACUCHILLA ASTILLADORA',
#        'REPOSICION RELE SEGURIDAD ASTILLADORA',
#        'sus. correas x 13 usadas', 'Sus fresa ejes alimt astilladora ***',
#        'Rep trans mandibula sup astilladora',
#        'Sus pinchos rodilla sup/inf  ultimo',
#        'Rep eje rodillo aceleración entra astill',
#        'REPARACIÓN CABLE 6KV ALIMENTACIÓN ASTILL',
#        'LEVANTAR CAPOTA DE ASTILLADORA PARA LIMP',
#        'SUST.PIÑON DE ARRASTRE DE MOTOR Y REDUCT',
#        'VACIADO FOSO DE LA ASTILLADORA', 'SUST. TAMIZ DE ASTILLADORA',
#        'Sus. protecciones amortiguadores soporta',
#        'LIMPIEZA FOSO ASTILLADORA',
#        'SUST.DIENTES RODILLOS PIÑA ASTILLADORA.(',
# ...

# %%
documents = newdataframe[newdataframe['wo_type'] == 'COR1']['wo_header_short'].values

# %%
documents
# Out:
# array(['sus. placa desgaste cuchilla', 'sustitución correas astilladora',
#        'sus rodillo pinchos astilladora',
#        'limpieza mandibula astilladora', 'sus. correas astilladora',
#        'sus. rodillo pinchos alimet astilladora',
#        'SUS. PEINE ENTRADA ASTILLADORA',
#        'SUS. CONTRACUCHILLA ASTILLADORA',
#        'REPOSICION RELE SEGURIDAD ASTILLADORA',
#        'sus. correas x 13 usadas',
#        'REPARACIÓN CABLE 6KV ALIMENTACIÓN ASTILL',
#        'REPARACION DE PISTON EXTRACTOR CONTRACUC',
#        'REPARACION BOTONERA AEREA POLIPASTO DE C',
#        'REPONER CABLES ZONA ENTRADA ASTILLADORA',
#        'REPARACION DEL 5º EJE INFERIOR DE LA AST',
#        'MONTAR PROTECCION ASTILLADORA PARA CABLE',
#        'SUSTITUIR CABEZA FINAL DE CARRERA CAPOTA',
#        'REPONER INTERRUPTOR CAMPO POLIPASTO ASTI',
#        'SUSTITUCION CABEZA FINAL CARRERA CAPOTA',
#        'SUSTITUIR FC BULON ASTILLADORA',
#        'SUSTITUCION SETA 22S3 TRAS LLEVARSE UN G',
# ...

# %%
TFIDF = TfidfVectorizer(tokenizer=tokenization_process)

# %%
TFIDF_matrix = TFIDF.fit_transform(documents)

# %%
terms = TFIDF.get_feature_names()

# %%
print(TFIDF_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-d9a6193c5695> in <module>()
# ----> 1 print(TFIDF_matrix.maximum())
#
# TypeError: maximum() missing 1 required positional argument: 'other'

# %%
len(terms)
# Out:
# 364

# %%
TFIDF_matrix.max()
# Out:
# 0.49779673387701884

# %%
def toptokens(Tfidfmatrix, tokens, n=20):
    npmatrix = Tfidfmatrix.toarray()
    npmatrix[npmatrix == 0] = np.nan
    npmeans = np.nanmean(npmatrix, axis = 0)
    ordered_ids = np.argsort(npmeans)[::-1] 
    clean_ids = ordered_ids[(np.isnan(npmeans).sum()):]
    top_ids = clean_ids[:n]
    toptoken = [(tokens[i], npmeans[i]) for i in top_ids]
    df = pd.DataFrame(toptoken)
    df.columns = ['feature', 'TF-IDF']
    return df

# %%
tokens = toptokens(TFIDF_matrix, terms)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-060bb1fd74a9> in <module>()
# ----> 1 tokens = toptokens(TFIDF_matrix, terms)
#
# NameError: name 'TFIDF_matrix' is not defined

# %%
tokens
# Out:
#           feature    TF-IDF
# 0  contracuchilla  0.761157
# 1        limpieza  0.710719
# 2     sustitución  0.710719
# 3           bulon  0.687398
# 4           peine  0.627872

# %%
import pandas as pd

# %%
error_table = pd.read_csv('data/errors.csv')
failure_table = pd.read_csv('data/failures.csv')
machine_table = pd.read_csv('data/machines.csv')
maint_table = pd.read_csv('data/maint.csv')
telemetry_table = pd.read_csv('data/telemetry.csv')

# %%
error_table
# Out:
#                   datetime  machineID errorID
# 0      2015-01-06 03:00:00          1  error3
# 1      2015-02-03 06:00:00          1  error4
# 2      2015-02-21 11:00:00          1  error1
# 3      2015-02-21 16:00:00          1  error2
# 4      2015-03-20 06:00:00          1  error1
# 5      2015-04-04 06:00:00          1  error5
# 6      2015-05-04 06:00:00          1  error4
# 7      2015-05-19 06:00:00          1  error2
# 8      2015-05-19 06:00:00          1  error3
# 9      2015-06-03 06:00:00          1  error5
# 10     2015-06-18 06:00:00          1  error2
# 11     2015-06-18 06:00:00          1  error3
# 12     2015-08-02 06:00:00          1  error4
# 13     2015-08-02 06:00:00          1  error5
# 14     2015-10-31 06:00:00          1  error5
# 15     2015-11-15 06:00:00          1  error1
# 16     2015-12-15 06:00:00          1  error5
# 17     2015-01-31 06:00:00          2  error2
# 18     2015-01-31 06:00:00          2  error3
# ...

# %%
failure_table
# Out:
#                  datetime  machineID failure
# 0     2015-02-04 06:00:00          1   comp3
# 1     2015-03-21 06:00:00          1   comp1
# 2     2015-04-05 06:00:00          1   comp4
# 3     2015-05-05 06:00:00          1   comp3
# 4     2015-05-20 06:00:00          1   comp2
# 5     2015-06-04 06:00:00          1   comp4
# 6     2015-06-19 06:00:00          1   comp2
# 7     2015-08-03 06:00:00          1   comp3
# 8     2015-08-03 06:00:00          1   comp4
# 9     2015-11-01 06:00:00          1   comp4
# 10    2015-11-16 06:00:00          1   comp1
# 11    2015-12-16 06:00:00          1   comp4
# 12    2015-01-02 03:00:00          2   comp2
# 13    2015-02-01 06:00:00          2   comp2
# 14    2015-04-02 06:00:00          2   comp2
# 15    2015-04-17 06:00:00          2   comp1
# 16    2015-06-01 06:00:00          2   comp2
# 17    2015-08-15 06:00:00          2   comp1
# 18    2015-09-29 06:00:00          2   comp1
# 19    2015-01-07 06:00:00          3   comp1
# ...

# %%
machine_table
# Out:
#      machineID   model  age
# 0            1  model2   18
# 1            2  model4    7
# 2            3  model3    8
# 3            4  model3    7
# 4            5  model2    2
# 5            6  model3    7
# 6            7  model4   20
# 7            8  model3   16
# 8            9  model1    7
# 9           10  model1   10
# 10          11  model4    6
# 11          12  model2    9
# 12          13  model3   15
# 13          14  model4    1
# 14          15  model4   14
# 15          16  model3    3
# 16          17  model4   14
# 17          18  model4   15
# 18          19  model4   17
# 19          20  model2   16
# 20          21  model3   14
# 21          22  model4   14
# 22          23  model3   17
# 23          24  model1   20
# 24          25  model4   16
# 25          26  model3    3
# 26          27  model2    9
# 27          28  model4    1
# 28          29  model3    3
# 29          30  model3   20
# ..         ...     ...  ...
# 970        971  model2    0
# ...

# %%
maint_table
# Out:
#                   datetime  machineID   comp  IF_FAIL
# 0      2014-07-01 06:00:00          1  comp4        0
# 1      2014-09-14 06:00:00          1  comp1        0
# 2      2014-09-14 06:00:00          1  comp2        0
# 3      2014-11-13 06:00:00          1  comp3        0
# 4      2015-01-05 06:00:00          1  comp1        0
# 5      2015-01-20 06:00:00          1  comp1        0
# 6      2015-02-04 06:00:00          1  comp3        1
# 7      2015-02-19 06:00:00          1  comp3        0
# 8      2015-03-06 06:00:00          1  comp3        0
# 9      2015-03-21 06:00:00          1  comp1        1
# 10     2015-04-05 06:00:00          1  comp1        0
# 11     2015-04-05 06:00:00          1  comp4        1
# 12     2015-04-20 06:00:00          1  comp1        0
# 13     2015-05-05 06:00:00          1  comp3        1
# 14     2015-05-20 06:00:00          1  comp2        1
# 15     2015-06-04 06:00:00          1  comp4        1
# ...

# %%
telemetry_table
# Out:
#                     datetime  machineID        volt      rotate    pressure  \
# 0        2015-01-01 06:00:00          1  151.919999  530.813578  101.788175
# 1        2015-01-01 07:00:00          1  174.522001  535.523532  113.256009
# 2        2015-01-01 08:00:00          1  146.912822  456.080746  107.786965
# 3        2015-01-01 09:00:00          1  179.530561  503.469990  108.283817
# 4        2015-01-01 10:00:00          1  180.544277  371.600611  107.553307
# 5        2015-01-01 11:00:00          1  141.411757  530.857266   87.614001
# 6        2015-01-01 12:00:00          1  184.083822  450.227529   87.697380
# 7        2015-01-01 13:00:00          1  166.632618  486.466838  108.067734
# 8        2015-01-01 14:00:00          1  159.892748  488.968697  102.131884
# 9        2015-01-01 15:00:00          1  176.686812  508.202759   90.951189
# 10       2015-01-01 16:00:00          1  189.209257  489.650433  105.406282
# ...
